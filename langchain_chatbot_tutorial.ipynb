# %% [markdown]
# <a href="https://colab.research.google.com/github/castilloadriana/agentLab/blob/main/langchain_chatbot_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LangChain Chatbot Tutorial 🤖
#
# ---
#
#
# Welcome to this beginner-friendly tutorial on building a chatbot with LangChain and LangGraph!
#
# ## What you'll learn:
# - How to set up a simple AI chatbot
# - Understanding the basic components of LangGraph
# - How to interact with Google's Gemini AI model
# - Building a conversational flow
#
# ## Prerequisites:
# - No prior Python knowledge required! We'll explain everything step by step
# - A Google API key (we'll show you how to get one)
#
# Let's get started! 🚀

# %% [raw]
# ```
# `# This is formatted as code`
# ```
#
#
# ```
# # This is formatted as code
# ```
#
# ## Step 1: Getting Your Google API Key 🔑
#
# Before we start coding, you'll need a Google API key to use the Gemini AI model.
#
# ### How to get your API key:
# 1. Go to [Google AI Studio](https://aistudio.google.com/app/apikey)
# 2. Sign in with your Google account
# 3. Click "Create API Key"
# 4. Copy the key (keep it safe!)
#
# ### Important Notes:
# - ⚠️ **Never share your API key publicly**
# - ⚠️ **Don't commit it to GitHub or other public repositories**
# - 💡 **Tip**: You can use Google AI Studio for free with rate limits
#
# Once you have your key, we'll show you how to use it safely!

# %% [raw]
# ## Step 2: Install Required Packages 📦
#
# First, we need to install the packages that our chatbot will use. Think of these as tools in a toolbox - each one has a specific job!

# %%
# Install the required packages
# This might take a few minutes the first time you run it

# %pip install langchain langgraph langchain-google-genai langchain-tavily

print("✅ Installation complete! Ready to build our chatbot.")
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.11/dist-packages (0.6.4)
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.11/dist-packages (2.1.9)
# Collecting langchain-tavily
#   Downloading langchain_tavily-0.2.11-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.4.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.6.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.2.0)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (3.5.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai) (0.6.18)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in /usr/local/lib/python3.11/dist-packages (from langchain-tavily) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.20.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.29.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.3.0,>=0.2.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.3.0,>=0.2.0->langgraph) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (1.3.1)
# Downloading langchain_tavily-0.2.11-py3-none-any.whl (26 kB)
# Installing collected packages: langchain-tavily
# Successfully installed langchain-tavily-0.2.11
# ✅ Installation complete! Ready to build our chatbot.

# %% [raw]
# ## Step 3: Set Up Your API Key 🔐
#
# Now we'll set up your Google API key. Replace `"your_api_key_here"` with the actual key you got from Google AI Studio.
#
# **Important**: This is just for learning purposes. In a real application, you'd store this more securely!

# %%
import os

# Replace "your_api_key_here" with your actual Google API key
# Make sure to keep the quotes around it!
from google.colab import userdata


os.environ["GOOGLE_API_KEY"] = "your_api_key_here"
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")


# This line checks if the key was set correctly
if os.environ.get("GOOGLE_API_KEY") == "your_api_key_here":
    print("⚠️  Don't forget to replace 'your_api_key_here' with your actual API key!")
else:
    print("✅ API key is set up!")
# Out:
# ✅ API key is set up!

# %% [raw]
# ## Step 4: Import the Tools We Need 🛠️
#
# Now let's import all the tools (libraries) we'll use to build our chatbot. Think of this like gathering all your ingredients before cooking!

# %%
# Import statements - these bring in the tools we need
from typing import Annotated                      # Helps with type hints (optional but good practice)
from typing_extensions import TypedDict           # Helps us define data structures

from langgraph.graph import StateGraph, START, END    # The main graph components
from langgraph.graph.message import add_messages      # Handles message management
from langchain.chat_models import init_chat_model     # Connects to AI models

print("✅ All tools imported successfully!")
# Out:
# ✅ All tools imported successfully!

# %% [raw]
# ## Step 5: Define the State Structure 📋
#
# In LangGraph, we need to define what information our chatbot will keep track of. Think of this as the chatbot's "memory" structure.
#
# For our chatbot, we only need to remember the conversation messages.

# %%
# Define what our chatbot will remember
class State(TypedDict):
    # This stores all the messages in our conversation
    # The `add_messages` part tells LangGraph to add new messages to the list
    # instead of replacing the whole list
    messages: Annotated[list, add_messages]

print("✅ State structure defined!")
print("Our chatbot will remember: messages in the conversation")
# Out:
# ✅ State structure defined!
# Our chatbot will remember: messages in the conversation

# %% [raw]
# ## Step 6: Connect to the AI Model 🧠
#
# Now we'll connect to Google's Gemini AI model. This is the "brain" that will generate responses to user messages.

# %%
# Connect to Google's Gemini AI model
# "gemini-2.0-flash" is a fast and capable version of Google's AI
llm = init_chat_model("google_genai:gemini-2.0-flash")

print("✅ Connected to Gemini AI!")
print("Model: gemini-2.0-flash")
# Out:
# ✅ Connected to Gemini AI!
# Model: gemini-2.0-flash

# %% [raw]
# ## Step 7: Create the Chatbot Function 💬
#
# Now we'll create the main function that handles conversations. This function takes the current state (all previous messages) and generates a new response.

# %%
# This function is the "brain" of our chatbot
def chatbot(state: State):
    """
    This function takes the conversation history and generates a response.

    How it works:
    1. Takes all the messages from the conversation so far
    2. Sends them to the AI model (Gemini)
    3. Gets back a response
    4. Returns the response in the format LangGraph expects
    """
    response = llm.invoke(state["messages"])
    return {"messages": [response]}

print("✅ Chatbot function created!")
print("This function will process messages and generate AI responses.")
# Out:
# ✅ Chatbot function created!
# This function will process messages and generate AI responses.

# %% [raw]
# ## Step 8: Build the Conversation Graph 🔗
#
# LangGraph uses a "graph" to define how conversations flow. Think of it like a flowchart:
# - START → Our chatbot function → END
#
# This creates a simple back-and-forth conversation pattern.

# %%
# Step 1: Create a graph builder
graph_builder = StateGraph(State)

# Step 2: Add our chatbot function as a "node" in the graph
# The first part ("chatbot") is just a name we give it
# The second part (chatbot) is our actual function
graph_builder.add_node("chatbot", chatbot)

# Step 3: Define the flow: START → chatbot → END
graph_builder.add_edge(START, "chatbot")  # When conversation starts, go to chatbot
graph_builder.add_edge("chatbot", END)    # After chatbot responds, end this turn

# Step 4: Build the final graph
graph = graph_builder.compile()

print("✅ Conversation graph built!")
print("Flow: START → chatbot function → END")
# Out:
# ✅ Conversation graph built!
# Flow: START → chatbot function → END

# %% [raw]
# ## Step 9: Test Your Chatbot! 🎉
#
# Now let's test our chatbot with a simple message. This function will send a message and show the response.

# %%
# Function to send a message and get a response
def send_message(user_input: str):
    """
    Send a message to the chatbot and display the response.
    """
    print(f"User: {user_input}")

    # Send the message through our graph
    for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
        for value in event.values():
            response = value["messages"][-1].content
            print(f"Assistant: {response}")
    print("-" * 50)  # Separator line

# Test with a simple message
send_message("What is CodePath")
# Out:
# User: What is CodePath
# Assistant: CodePath is a non-profit organization dedicated to bridging the gap between computer science education and industry expectations. They provide **free, comprehensive training programs** in mobile development, web development, and cybersecurity to college students, particularly those from underrepresented backgrounds.
#
# Here's a breakdown of what CodePath is and what it offers:
#
# **Key Features and Goals:**
#
# *   **Industry-Aligned Curriculum:** CodePath's curriculum is designed in collaboration with industry experts from companies like Facebook (Meta), Google, Microsoft, and more. This ensures students learn the skills and technologies that are highly sought after by employers.
# *   **Hands-on Learning:** CodePath emphasizes practical, project-based learning. Students build real-world applications, gaining valuable experience that prepares them for internships and jobs.
# *   **Community and Mentorship:** CodePath fosters a strong community of students, instructors, and industry mentors. Students receive support and guidance throughout the program.
# *   **Access for Underrepresented Groups:** A core mission of CodePath is to increase diversity and inclusion in the tech industry. They actively recruit and support students from underrepresented backgrounds, including women, people of color, and students from low-income families.
# *   **Free for Students:** CodePath's programs are completely free for students. They are funded by donations from tech companies, foundations, and individuals.
# *   **Partnerships with Universities:** CodePath partners with colleges and universities across the United States to integrate its curriculum into their computer science programs. This allows more students to access CodePath's training.
# * **Career Support:** CodePath provides career services, including resume reviews, mock interviews, and networking opportunities, to help students land internships and full-time jobs.
#
# **Types of Programs Offered:**
#
# *   **Mobile Development:** Android and iOS development tracks.
# *   **Web Development:** Full-stack web development with modern frameworks like React.
# *   **Cybersecurity:** Hands-on training in cybersecurity principles and practices.
# *   **Introductory Courses:**  They also offer intro courses to programming and mobile development.
#
# **Benefits of Participating in CodePath:**
#
# *   **Improved Skills:** Develop in-demand technical skills that are highly valued by employers.
# *   **Career Advancement:** Increase your chances of landing internships and full-time jobs in the tech industry.
# *   **Networking Opportunities:** Connect with industry professionals and build your network.
# *   **Community Support:** Join a supportive community of students and mentors.
# *   **Increased Confidence:** Gain the confidence and skills you need to succeed in the tech industry.
#
# **In summary, CodePath is a valuable resource for college students who are serious about pursuing a career in software engineering or cybersecurity.  It provides free, high-quality training that prepares students for the demands of the tech industry, with a particular focus on increasing diversity and inclusion.**
# --------------------------------------------------

# %% [raw]
# ## Step 10: Try More Examples! 🎮
#
# Now that your chatbot is working, try asking it different questions. Each cell below contains a different example - run them to see how your chatbot responds!

# %%
# Example 1: Ask about programming
send_message("Can you explain what Python is in simple terms?")

# %%
# Example 2: Ask for help with something
send_message("I'm new to AI and chatbots. What should I learn next?")

# %%
# Example 3: Try a creative question
send_message("Write a short poem about robots learning to code")

# %% [raw]
# ## Step 11: Interactive Chat Mode 💬
#
# Want to have a longer conversation? The cell below creates an interactive chat where you can type messages and get responses.
#
# **Note**: This works best in Jupyter environments that support interactive input.

# %%
# Interactive chat session
print("🤖 Welcome to your chatbot!")
print("Type your messages below. Type 'quit' to exit.")
print("=" * 50)

try:
    while True:
        # Get user input
        user_input = input("\nYou: ")

        # Check if user wants to quit
        if user_input.lower() in ["quit", "exit", "q", "bye"]:
            print("Chatbot: Goodbye! Thanks for chatting! 👋")
            break

        # Send message to chatbot
        print("Chatbot: ", end="")
        for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
            for value in event.values():
                response = value["messages"][-1].content
                print(response)

except KeyboardInterrupt:
    print("\n\nChatbot: Goodbye! Thanks for chatting! 👋")
except:
    print("\n\nNote: Interactive input might not work in all environments.")
    print("If you see this message, try using the send_message() function instead!")
# Out:
# 🤖 Welcome to your chatbot!
# Type your messages below. Type 'quit' to exit.
# ==================================================
#
# You: Tell me about securing my taxes
# Chatbot: Securing your taxes involves protecting your personal and financial information to prevent identity theft and tax fraud, as well as ensuring you're filing accurately and on time to avoid penalties. Here's a breakdown of key areas:
#
# **I. Protecting Your Information (Preventing Identity Theft and Tax Fraud):**
#
# *   **Strong Passwords and Account Security:**
#     *   Use strong, unique passwords for all online accounts, especially those related to finances and taxes (IRS, banks, tax software).
#     *   Enable multi-factor authentication (MFA) whenever possible. This adds an extra layer of security, requiring a code from your phone or email in addition to your password.
#     *   Be wary of phishing emails, texts, and phone calls.  The IRS *never* initiates contact via email or social media to request personal or financial information.  They always use postal mail.  Never click on links or download attachments from suspicious sources.  If you think it may be a legitimate email, go to the company's website directly and log in.
#     *   Monitor your credit report regularly for any unauthorized activity.  You can get a free credit report from each of the three major credit bureaus (Equifax, Experian, TransUnion) annually through [AnnualCreditReport.com](https://www.annualcreditreport.com/).
# *   **Secure Storage of Documents:**
#     *   Store sensitive tax documents (W-2s, 1099s, bank statements, etc.) in a secure location. This could be a locked filing cabinet, a password-protected digital folder, or a secure cloud storage service.
#     *   Shred any documents containing personal or financial information before discarding them.
#     *   Be careful when using public Wi-Fi. Avoid accessing sensitive financial information on unsecured networks. Use a VPN (Virtual Private Network) to encrypt your internet traffic.
# *   **Tax Software Security:**
#     *   Use reputable tax preparation software.
#     *   Keep your tax software up to date with the latest security patches.
#     *   Choose strong passwords for your tax software accounts.
#     *   Be cautious about sharing your tax information with unauthorized individuals or websites.
# *   **Protecting Your Social Security Number (SSN):**
#     *   Be very cautious about sharing your SSN. Only provide it when absolutely necessary and to trusted sources.
#     *   Store your Social Security card in a safe place.
# *   **Recognize and Report Suspicious Activity:**
#     *   If you suspect you've been a victim of identity theft, report it immediately to the IRS, the Federal Trade Commission (FTC), and your financial institutions.
#     *   File an identity theft affidavit with the IRS (Form 14039).
#     *   Consider placing a fraud alert on your credit report.
#
# **II. Accurate and Timely Filing (Avoiding Penalties):**
#
# *   **Keep Accurate Records:**
#     *   Maintain organized records of your income, expenses, and deductions throughout the year. This will make filing your taxes much easier and more accurate.
#     *   Use a system that works for you, whether it's a spreadsheet, accounting software, or a simple filing system.
# *   **Know Your Deadlines:**
#     *   The standard deadline for filing your federal income tax return is April 15th (though this can shift slightly due to weekends or holidays).
#     *   If you need more time, file for an extension (Form 4868) by the April deadline. An extension gives you until October 15th to file, but it *does not* extend the time to pay any taxes owed.
#     *   Be aware of deadlines for estimated tax payments if you are self-employed or have income not subject to withholding.
# *   **Choose the Right Filing Method:**
#     *   **E-filing:**  The most secure and efficient way to file your taxes. It reduces errors and provides faster refunds. Use IRS Free File if you qualify, or choose a reputable tax software provider.
#     *   **Paper Filing:** While still an option, it's slower and more prone to errors. Mail your return to the correct IRS address.
#     *   **Tax Professional:**  Consider hiring a qualified tax professional (CPA, Enrolled Agent) if your tax situation is complex or you need assistance.  Make sure they have a Preparer Tax Identification Number (PTIN) from the IRS.
# *   **Double-Check Your Return:**
#     *   Before filing, carefully review your tax return for any errors or omissions. Even small mistakes can cause delays or trigger an audit.
#     *   Make sure you have entered your SSN and other personal information correctly.
#     *   Verify that all income and deduction amounts are accurate.
# *   **Pay Your Taxes on Time:**
#     *   If you owe taxes, pay them by the deadline to avoid penalties and interest.
#     *   The IRS offers several payment options, including online, by phone, by mail, or through direct debit.
#     *   If you can't afford to pay your taxes in full, contact the IRS to explore payment options, such as an installment agreement.
# *   **Keep a Copy of Your Return:**
#     *   Keep a copy of your filed tax return and all supporting documentation for at least three years (or longer if you claimed a loss or deduction that could be carried forward).
#
# **III. Choosing a Tax Professional (If Applicable):**
#
# *   **Credentials:** Look for a CPA (Certified Public Accountant), Enrolled Agent (EA), or attorney specializing in tax law.  EAs are licensed by the IRS.
# *   **Experience:**  Choose someone with experience in your specific tax situation (e.g., self-employment, rental income, investments).
# *   **Reputation:**  Check online reviews and ask for referrals from friends or family.
# *   **Fees:**  Understand how the tax professional charges (e.g., hourly rate, flat fee) and get a written agreement outlining the services and fees.
# *   **PTIN:**  Ensure the preparer has a valid Preparer Tax Identification Number (PTIN) from the IRS.
# *   **Ask Questions:**  Don't hesitate to ask the tax professional questions about their qualifications, experience, and approach to your tax situation.
#
# **IV. Specific IRS Resources:**
#
# *   **IRS Identity Theft Central:**  [https://www.irs.gov/identity-theft-central](https://www.irs.gov/identity-theft-central)
# *   **IRS Publication 4524, Security Awareness for Taxpayers:**  [https://www.irs.gov/pub/irs-pdf/p4524.pdf](https://www.irs.gov/pub/irs-pdf/p4524.pdf)
# *   **IRS Free File:** [https://www.irs.gov/e-file/free-file-do-your-federal-taxes-for-free](https://www.irs.gov/e-file/free-file-do-your-federal-taxes-for-free)
#
# By taking these steps, you can significantly reduce your risk of tax-related identity theft and ensure that you file your taxes accurately and on time.  Remember to stay vigilant and informed about the latest tax scams and security threats.
#
# You: q
# Chatbot: Goodbye! Thanks for chatting! 👋

# %% [raw]
# ## 🎓 Congratulations! You've Built a Chatbot!
#
# ### What You've Learned:
# - ✅ How to set up LangChain and LangGraph
# - ✅ How to connect to Google's Gemini AI model
# - ✅ How to define state management for conversations
# - ✅ How to create a simple conversation flow
# - ✅ How to test and interact with your chatbot
#
# ### What's Next?
# Here are some ideas to expand your chatbot:
#
# 1. **Add Memory**: Make the chatbot remember conversation history across sessions
# 2. **Add Tools**: Give your chatbot the ability to search the web, do calculations, etc.
# 3. **Improve Responses**: Add system prompts to give your chatbot a personality
# 4. **Add Error Handling**: Make your chatbot more robust with better error handling
# 5. **Create a Web Interface**: Build a web app around your chatbot
#
# ### Resources to Continue Learning:
# - [LangChain Documentation](https://python.langchain.com/)
# - [LangGraph Documentation](https://langchain-ai.github.io/langgraph/)
# - [Google AI Studio](https://aistudio.google.com/)
#
# Great job building your first AI chatbot! 🚀
